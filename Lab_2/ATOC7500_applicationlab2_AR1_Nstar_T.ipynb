# %%
### ATOC7500 Application Lab #2 - ATOC7500_applicationlab2_AR1_Nstar
### Written by Jennifer Kay (CU), Elizabeth Maroon (CU), and Hannah Zanowski (CU)
### Last updated September 23, 2020

##LEARNING GOALS:
##1) Calculate the autocorrelation at a range of lags using two methods available in python (np.correlate, dot products)
##2) Estimate the effective sample size (N*) using the lag-1 autocorrelation
##3) Evaluate the influence of changing the sampling frequency on the autocorrelation and on N*.

import numpy as np
import matplotlib
# %matplotlib inline
import matplotlib.pyplot as plt
import xarray
import pandas as pd   ##pandas reads in .csv.
from scipy import stats
import seaborn as sns  ### seaborn just makes things pretty -- no new typing
sns.set_style('whitegrid')  ###  change away from grey grid (seaborn default) to white grid

# %%
## Read in the data
import os #change directory to where there is data, not local GitHub repo
os.chdir('/Users/chwy8767/Google Drive/ATOC_7500_Data_Analysis/Lab2')

filename = 'christman_2016.csv'
data=pd.read_csv(filename,sep=',')
data.head()
# Out:
#      day      hour  temp_F    RH  dewtemp_F  wind_mph  wind_dir  windgust  \
# 0  42370  0.000000     7.0  72.2       -0.1       1.2       234       3.9
# 1  42370  0.041667     5.4  74.3       -1.0       3.4       299       7.1
# 2  42370  0.083333     6.4  73.8       -0.2       2.8       200       7.0
# 3  42370  0.125000     3.0  73.5       -3.6       2.9       309       6.1
# 4  42370  0.166667     3.7  76.9       -1.9       3.1       346       5.3
#
#    windgust_dir  pres_Hg  SOLIN_Wm2  Prec_inches
# 0           224   851.30        0.0          0.0
# 1           302   850.82        0.0          0.0
# 2           301   849.83        0.0          0.0
# 3           349   850.69        0.0          0.0
# 4           255   848.24        0.0          0.0

# %%
## Plot midnight temperature data for Fort Collins, Colorado
X=data['temp_F']
X_daily=X[::24] ## sample the hourly data every 24 hours
print('minimum data value: ',X_daily.min())
print('maximum data value: ',X_daily.max())

xindex = (np.arange(0,np.size(X),1))/24.
xindex_daily=xindex[::24] ## sample the index every 24 hours, to get day 1,2,3,4,5...

fig = plt.figure(figsize=[15,7])
plt.plot(xindex_daily, X_daily, linewidth = 1)
v = np.std(X_daily)
plt.text(0.95, 0.925,'$\sigma = $' + str(np.round(v)) + '$^o$F', ha='right', transform=plt.gca().transAxes, color = 'k')
ymin, ymax = plt.ylim();
xmin, xmax = plt.xlim();
lines = plt.plot((xmin, xmax),(0, 0),(0, 0),(ymin, ymax));
plt.setp(lines,color='black', linewidth=1);
plt.ylim((ymin, ymax));
plt.xlim((xmin, xmax));
plt.ylabel('Temperature (deg. F)');
plt.xlabel('Day');
plt.title('Hourly midnight temperature - Fort Collins, Colorado');
# Out:
# minimum data value:  -14.3
# maximum data value:  80.1

# %%
#Find the lag-one autocorrelation (AR1)
tseries=X_daily
sigma=np.std(tseries)  ## calculate the standard deviation
mean=np.mean(tseries)  ## calculate the mean
n=len(tseries)         ## calculate the length of the timeseries
lag=1                  ## warning: you cannot change this to be a negative lag. 
                       ## this cell does not work for negative lags - Can you see why?

## remove the mean
tseries1=tseries-mean

lag_list = np.concatenate((np.arange(-40,0,1),np.arange(1,41,1)))
autocor_list = np.array([])

for lag in lag_list:

    ##Create two timeseries of the data at t=t1 and t=t2
    t1_m=tseries1[0:-1*np.abs(lag)]
    t2_m=tseries1[np.abs(lag):]
    #print(t1_m.shape)
    #print(t2_m.shape)

    #Method #1
    #Calculate the autocorrelation using numpy correlate lagN
    lagNauto_np=np.correlate(t1_m,t2_m,mode='valid')/(n-np.abs(lag))/(sigma**2)
#     print('lag',lag,'autocorrelation np.correlate:',round(lagNauto_np[0],6))

    #Method #2 - direct calculation
    #Calculate the autocorrelation using numpy dot
    ## (https://docs.scipy.org/doc/numpy-1.13.0/reference/generated/numpy.dot.html)
    lagNauto=np.dot(t1_m,t2_m)/(n-abs(lag))/sigma**2 ## Barnes Chapter 2 Eq. 68 divided by the variance
    print('lag',lag,'autocorrelation direct calc:',round(lagNauto,6))
    
    autocor_list = np.append(autocor_list, lagNauto)
    
    if lag==1: alpha=lagNauto
# Out:
# lag -40 autocorrelation direct calc: 0.402639
# lag -39 autocorrelation direct calc: 0.41219
# lag -38 autocorrelation direct calc: 0.426973
# lag -37 autocorrelation direct calc: 0.43725
# lag -36 autocorrelation direct calc: 0.452812
# lag -35 autocorrelation direct calc: 0.471716
# lag -34 autocorrelation direct calc: 0.482077
# lag -33 autocorrelation direct calc: 0.497288
# lag -32 autocorrelation direct calc: 0.503518
# lag -31 autocorrelation direct calc: 0.525515
# lag -30 autocorrelation direct calc: 0.556639
# lag -29 autocorrelation direct calc: 0.557489
# lag -28 autocorrelation direct calc: 0.554142
# lag -27 autocorrelation direct calc: 0.54913
# lag -26 autocorrelation direct calc: 0.564951
# lag -25 autocorrelation direct calc: 0.5763
# lag -24 autocorrelation direct calc: 0.594479
# lag -23 autocorrelation direct calc: 0.605342
# lag -22 autocorrelation direct calc: 0.611804
# lag -21 autocorrelation direct calc: 0.621705
# lag -20 autocorrelation direct calc: 0.616266
# lag -19 autocorrelation direct calc: 0.639135
# lag -18 autocorrelation direct calc: 0.636503
# lag -17 autocorrelation direct calc: 0.649709
# lag -16 autocorrelation direct calc: 0.663487
# lag -15 autocorrelation direct calc: 0.672072
# lag -14 autocorrelation direct calc: 0.682044
# lag -13 autocorrelation direct calc: 0.689832
# lag -12 autocorrelation direct calc: 0.697155
# lag -11 autocorrelation direct calc: 0.725013
# lag -10 autocorrelation direct calc: 0.725221
# lag -9 autocorrelation direct calc: 0.747238
# lag -8 autocorrelation direct calc: 0.748523
# lag -7 autocorrelation direct calc: 0.75015
# lag -6 autocorrelation direct calc: 0.735265
# lag -5 autocorrelation direct calc: 0.742603
# lag -4 autocorrelation direct calc: 0.740638
# lag -3 autocorrelation direct calc: 0.735241
# lag -2 autocorrelation direct calc: 0.779235
# lag -1 autocorrelation direct calc: 0.84587
# lag 1 autocorrelation direct calc: 0.84587
# lag 2 autocorrelation direct calc: 0.779235
# lag 3 autocorrelation direct calc: 0.735241
# lag 4 autocorrelation direct calc: 0.740638
# lag 5 autocorrelation direct calc: 0.742603
# lag 6 autocorrelation direct calc: 0.735265
# lag 7 autocorrelation direct calc: 0.75015
# lag 8 autocorrelation direct calc: 0.748523
# lag 9 autocorrelation direct calc: 0.747238
# lag 10 autocorrelation direct calc: 0.725221
# lag 11 autocorrelation direct calc: 0.725013
# lag 12 autocorrelation direct calc: 0.697155
# lag 13 autocorrelation direct calc: 0.689832
# lag 14 autocorrelation direct calc: 0.682044
# lag 15 autocorrelation direct calc: 0.672072
# lag 16 autocorrelation direct calc: 0.663487
# lag 17 autocorrelation direct calc: 0.649709
# lag 18 autocorrelation direct calc: 0.636503
# lag 19 autocorrelation direct calc: 0.639135
# lag 20 autocorrelation direct calc: 0.616266
# lag 21 autocorrelation direct calc: 0.621705
# lag 22 autocorrelation direct calc: 0.611804
# lag 23 autocorrelation direct calc: 0.605342
# lag 24 autocorrelation direct calc: 0.594479
# lag 25 autocorrelation direct calc: 0.5763
# lag 26 autocorrelation direct calc: 0.564951
# lag 27 autocorrelation direct calc: 0.54913
# lag 28 autocorrelation direct calc: 0.554142
# lag 29 autocorrelation direct calc: 0.557489
# lag 30 autocorrelation direct calc: 0.556639
# lag 31 autocorrelation direct calc: 0.525515
# lag 32 autocorrelation direct calc: 0.503518
# lag 33 autocorrelation direct calc: 0.497288
# lag 34 autocorrelation direct calc: 0.482077
# lag 35 autocorrelation direct calc: 0.471716
# lag 36 autocorrelation direct calc: 0.452812
# lag 37 autocorrelation direct calc: 0.43725
# lag 38 autocorrelation direct calc: 0.426973
# lag 39 autocorrelation direct calc: 0.41219
# lag 40 autocorrelation direct calc: 0.402639

# %%
plt.figure(figsize=[15,8])
plt.plot(lag_list, autocor_list)

# %% [markdown]
# ### Barnes Ch 2 (68) $\gamma (\tau) = \overline{x'(t) x'(t+\tau)}$
# ### Here we use $\gamma (\tau) = \frac{\overline{x'(t) x'(t+\tau)}}{\sigma^2}$ or $\gamma (\tau) = \frac{\frac{x'(t) x'(t+\tau)}{N-1}}{\sigma^2}$

# %%
# Calculate the autocorrelation at all lags and plot it
# Is it symmetric about 0 lag?  Should it be? (hint: the answer is yes)
tseries1=tseries-mean
half=int(len(tseries)/2)
lags=np.arange(-1*half,half,1.)
#print(len(tseries1))
#print(len(lags))
#print(len(np.correlate(tseries1,tseries1,mode='same')))
autocorrelation_function=np.correlate(tseries1,tseries1,mode='same')/((n-np.abs(lags))*sigma**2)  ##Eq. 67 divided by variance
plt.plot(range(-1*half,half),autocorrelation_function)
plt.xlim([-40,40]);
plt.ylim([0.0,1.0]);
plt.xlabel('Lag (Days)',fontsize=14);
plt.ylabel('Autocorrelation',fontsize=14);

# %% [markdown]
# ### Barnes Ch 2 (88) $\frac{N^*}{N} \cong \frac{1- \rho(\Delta t)}{1+\rho(\Delta t)}$
# ### Barnes Ch 2 (90) $\frac{N^*}{N} \cong \frac{\Delta t}{2 T_e} = \frac{\Delta t}{-2 \frac{\Delta t}{ln(a)}} = \frac{ln(a)}{-2}$

# %%
## Calculate the effective sample size (N*) for this data 
## Compare your estimate of the number of independent samples (N*) with the number of samples 
## in your original data (N)
N=len(tseries)
print('# samples, N: ',N)
print('lag-1 autocorrelation: ',round(alpha,4))
print('#independent samples, N*: ',round((1-np.abs(alpha))/(1+np.abs(alpha))*N,3)) ## Chapter 2 Barnes Eq. 88
## Note that the value of the autocorrelation used in Eq. 88 should be the absolute value otherwise
## if alpha is negative you end up with more independent samples than original samples
# Out:
# # samples, N:  366
# lag-1 autocorrelation:  0.8459
# #independent samples, N*:  30.561
